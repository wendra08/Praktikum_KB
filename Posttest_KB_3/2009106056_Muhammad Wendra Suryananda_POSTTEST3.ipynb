# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_Life_Expectancy = pd.read_csv("Life Expectancy Data.csv")

# %%
dataset_Life_Expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# #### Mengelompokkan berdasarkan jumlah dari attribute status

# %%
data_pie = dataset_Life_Expectancy['Status'].value_counts().rename_axis('Status').reset_index(name='Id_count')

# %% [markdown]
# ### pltfigure berguna untuk mengubah ukuran output gambar
# - colors mengubah warna
# - explode berguna untuk memisahkan salah satu bagan di pie chart
# - plt pie maksudnya ngambil dari variabel data_pie yang sudah dideklarasikan di atas dengan labels yg diambil adalah status
# - autopct untuk menampilkan persentase, shadow memberikan bayangan, startangle untuk merotasi grafik pie sebanyak 90 derajat
# - plt tittle memberikan judul

# %%
plt.figure(figsize=(5,5))
colors = sns.color_palette('bright')
explode = [0.1,0]
plt.pie(data_pie['Id_count'], labels=data_pie.Status,
autopct='%1.1f%%', shadow=True, startangle=90, explode=explode)
plt.title("Data Persentase status negara")
plt.show()

# %% [markdown]
# ## Diagram Pie
# - dari data persentase status negara, negara maju lebih sedikit jumlahnya karena seperti yang kita negara di dunia lebih sedikit negara maju dari pada negara berkembang
# - dari data persentase status negara, negara berkembang lebih banyak jumlahnya dari negara maju, karena hampir seluruh negara di dunia adalah negara berkembang, contohnya Indonesia

# %% [markdown]
# ### Diagram Garis
# flt figure untuk merubahkan ukuran gambar
# - dfevelopiing dan dfdeveloper berguna untuk ngesubset atau ngefilter
# - sns.set_style untuk merubah styling background
# - groupby dikelompokkan berdasarkan tahun dan GDP rata rata

# %%
plt.figure(figsize=(10,7))
dfDeveloping = df[df["Status"] == "Developing"]
dfDeveloped = df[df["Status"] == "Developed"]

sns.set_style("darkgrid")
dfYearDeveloped = dfDeveloped.groupby("Year")["GDP"].mean()
dfYearDeveloping = dfDeveloping.groupby("Year")["GDP"].mean()


sns.lineplot(data=dfYearDeveloped,x=dfYearDeveloped.index,y=dfYearDeveloped,label="Negara Maju")
sns.lineplot(data=dfYearDeveloping,x=dfYearDeveloping.index,y=dfYearDeveloping,label="Negara Berkembang")
plt.xlabel("Pertahun Pendapatan Nasional")
plt.ylabel("Pendapatan Nasional")
plt.legend()
plt.title("Grafik Perbandingan Pendapatan Nasional Negara & Negara Berkembang")
# Out:
# Text(0.5, 1.0, 'Grafik Perbandingan Pendapatan Nasional Negara & Negara Berkembang')

# %% [markdown]
# ## Grafik Garis
# - dalam grafik ini kita dapat melihat perbandingan di tahun 2000 negara maju pendapatan nasional negaranya berada di 15000 dan dinegara berkembang sangat rendah sekali pendapatan nasionalnya yaitu di bawah 5000
# - ditahun 2008 negara maju memiliki kenaikkan paling tinggi dikarenakan harga dollar pada saat itu cukup melesat tinggi harganya. tetapi untuk negara berkembang kenaikan dollar dinegara maju tersebut sedikit berpengaruh untuk negara berkembang, karena yang kita lihat dari tahun 2008 pendapatan nasional negara berkembang lebih naik dari pada tahun - tahun sebelumnya.

# %% [markdown]
# ### Histogram
# - sns histoplat buat grafik histogramnya diambil dari data df x adalah total expenditure bins itu jumlah yang ditampilkan, hue buat nampilkan statusnya
# - plt.title untuk memberikan judul
# - xlabel untuk menamai label x
# - ylabel untuk menamai label y

# %%
sns.histplot(data=df, x="Total expenditure",bins=10, hue="Status")
plt.title("Diagram pesebaran pengeluaran")
plt.xlabel("Jumlah Pengeluaran")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ## Grafik Histogram
# - dari grafik histogram ini jumlah pengeluaran dari 5.0 sampai 7.5 memiliki jumlah pengeluaran yang paling tinggi dari tahun-tahun yang lainnya.
# - dari grafik histogram jumlah pengeluaran 2.5 sampai 5.0 memiliki jumlah kenaikan 790 jumlah.
# - jumlah pengeluaran dengan jumlah paling kecil dari 12.5 sampai 17.5
